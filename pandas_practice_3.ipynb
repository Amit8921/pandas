# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit8921/pandas/blob/main/pandas_practice_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/dat_pd/imdb_data.csv'
df=pd.read_csv(file_path)

# %%
df.shape
# Out:
# (3000, 23)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
# SO LETS TALK ABOUT 'APPLY METHOD'

# %%
df['title'].head(5)
# Out:
# 0                      Hot Tub Time Machine 2
# 1    The Princess Diaries 2: Royal Engagement
# 2                                    Whiplash
# 3                                     Kahaani
# 4                                  Marine Boy
# Name: title, dtype: object

# %%
# Suppose we want to convert the column network to uppercase

def to_uppercase(column):
  return column.upper()

# %%
df['Capitalized_title'] = df['title'].apply(to_uppercase)
# SO WE ADD ONE COLUMN THAT IS 'CAPITALIZED TITTLE' USING APPLY FUNCTION ,IT CONVERTS THE VALUE OF TITTLE TO UPPERCASE

# %%
df.head(5)
# SO WE SEE IN THE OUTPUT THAT IN THE LAST COLUMN 'CAPITALIZED COLUMN' AND ITS TITTLE VALUE CONVERTS TO UPPERCASE
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['Capitalized_title'].head(5)
   # SO WE ALSO SEE THAT THE VALUES ARE CONVERT TO 'UPPERCASE'
# Out:
# 0                      HOT TUB TIME MACHINE 2
# 1    THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2                                    WHIPLASH
# 3                                     KAHAANI
# 4                                  MARINE BOY
# Name: Capitalized_title, dtype: object

# %%
# LETS TALK ABOUT LAMBDA FUNCTION

# %%
x=lambda a,b:a+b
x(1,6)
# Out:
# 7

# %%
x=lambda a,b,c,d:a*b+c-d
x(2,3,4,5)
# Out:
# 5

# %%
# lambda function - Row wise operation
def revised_profit(revenue, budget):
  if revenue > 0:
    new_profit = revenue - budget
  else:
    new_profit = np.nan

  return new_profit

# %%
df['new_profit'] = df.apply(lambda x: revised_profit(x['revenue'], x['budget']),axis=1)
 # SO COLLON KE PEHLE JO X H VO INPUT H AND COLLON KE BAAD KE TERM OUTPUT

# %%
df.head(4)
# SO WE SEE OUTPUT IN THE LAST GENERATED COLUMN THAT IS "NEW PROFIT"
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
#
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)

# SO WE SEE THE OUTPUT THAT IS VALUES ARE SORTED AND WE SEE THAT INDEX POSITIONS ALSO CHANGED
# Out:
#         id                              belongs_to_collection    budget  \
# 1211  1212                                                NaN  18000000
# 1922  1923                                                NaN  31115000
# 523    524                                                NaN  13000000
# 1302  1303                                                NaN  44000000
# 1914  1915                                                NaN  56000000
# ...    ...                                                ...       ...
# 2785  2786                                                NaN         0
# 2865  2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2498  2499  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# 1335  1336                                                NaN   6000000
# 2302  2303                                                NaN         0
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
# We can also sort by the combination of two columns
df.sort_values(['status','new_profit'], ascending=[False,True])
# SO WE SORT STATUS IN DECENDING ORDER AND NEW PROFIT IN ASCENDING ORDER
# Out:
#         id                              belongs_to_collection     budget  \
# 1618  1619                                                NaN     891000
# 1007  1008                                                NaN          0
# 609    610  [{'id': 144200, 'name': 'Swan Princess Series'...          0
# 1216  1217                                                NaN          0
# 2623  2624                                                NaN  197471676
# ...    ...                                                ...        ...
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 684    685                                                NaN  160000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
#
#                                                  genres  \
# ...

# %%
df['release_date'][0:5]
# Out:
# 0     2/20/15
# 1      8/6/04
# 2    10/10/14
# 3      3/9/12
# 4      2/5/09
# Name: release_date, dtype: object

# %%
# LET EXPLORE UNIQUE AND MISSING VALUES

# %%
set(df['status'].to_list())
  # WE ALL KNOW THAT SET GIVES UNIQUE VALUES
# Out:
# {'Released', 'Rumored'}

# %%
# Find the list of unique values in a column
list(df['status'].unique())  # SO IN THIS CODE WE USE "UNIQUE" METHOD
# Out:
# ['Released', 'Rumored']

# %%
list(df['original_language'].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
# Counts the number of unique values in a column
df.original_language.nunique()  # IN THIS CODE WE USE NUNIQUE METHOD
# Out:
# 36

# %%
# Give the counts of each category of a variable
df['original_language'].value_counts()
  # HERE WE COUNT THE UNIQUE VALUES PRESENT IN HOW MANY ROWS USING 'VALUE_COUNTS' METHODS
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
#  Returns a series of booleans if a column value contains nulls using "isnull method"
df['homepage'].isnull()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998    False
# 2999    False
# Name: homepage, Length: 3000, dtype: bool

# %%
df[df['homepage'].isnull()]
# IT SHOWS ALL THE ROWS CORRESPONDING TO 'HOMEPAGE COLUMN' THAT HAS NULL VALUES ,BY UNDERSTANDING SEE HOMEPAGE COLUMN
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 4        5                                                NaN         0
# 5        6                                                NaN   8000000
# 7        8                                                NaN         0
# ...    ...                                                ...       ...
# 2992  2993                                                NaN   1135654
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
#
#                                                  genres homepage    imdb_id  \
# ...

# %%
df[~df['homepage'].isnull()]  # HERE WE USE TILDA(~) OPERATOR THAT GIVES REVERSE THE CONDITION APPLY ON PREVIOUS QUESTION,SEE HOMEPAGE FOR
                                                                 # BETTER UNDERSTANDING
# Out:
#         id                              belongs_to_collection    budget  \
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# 15      16                                                NaN    500000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
# lets fill the missing values with the value using 'FILLNA' METHOD, SO HERE WE FILL NULL VALUES TO 'NOT PRESENT' IN HOMEPAGE COLUMN
df['homepage'].fillna('Not Present',inplace = True)

# %%
df['homepage']
# Out:
# 0                             Not Present
# 1                             Not Present
# 2       http://sonyclassics.com/whiplash/
# 3              http://kahaanithefilm.com/
# 4                             Not Present
#                       ...
# 2995                          Not Present
# 2996                          Not Present
# 2997                          Not Present
# 2998       http://www.alongcamepolly.com/
# 2999     http://www.abductionthefilm.com/
# Name: homepage, Length: 3000, dtype: object
